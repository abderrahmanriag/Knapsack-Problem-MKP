# %%
import operation

operation.main()
# Out:
# create the init population...
# best solution in init population =16537
# crossover probability pc=0.2, and pc=0.7
# build 500 generations...
# cap=['36577', '36182', '38612', '37338', '36798']
# weights=[36567, 34752, 38422, 36790, 35652], value=68201
# running time:153.16754865646362
