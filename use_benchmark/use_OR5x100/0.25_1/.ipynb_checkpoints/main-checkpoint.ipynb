# %% [markdown]
# ## Comparison between GA and GGA

# %%
import GGAvsGA as g    
g.main()
# Out:
# create the init population...
# best solution in init population =16795
# build 500 generations...
# Camparison the GGA with GA, crossover probability=0.2
# cap=['11927', '13727', '11551', '13056', '13460']
# weights=[11760, 13667, 11373, 12992, 12970], value=24095
# running time:65.91922450065613

# %% [markdown]
# ## Build 500 generations with deffirent crossover probability

# %%
import operation
operation.main()
# Out:
# create the init population...
# best solution in init population =16893
# crossover probability pc=0.2, and pc=0.1
# build 500 generations...
# cap=['11927', '13727', '11551', '13056', '13460']
# weights=[11658, 13723, 11503, 12893, 12213], value=24361
# running time:102.2370216846466
