# %%
import operation

def main():
    operation.main()
    
main()
# Out:
# create the init population...
# best solution in init population =17030
# crossover probability pc=0.2, and pc=0.7
# build 500 generations...
# cap=['11927', '13727', '11551', '13056', '13460']
# weights=[11558, 13552, 11535, 12899, 12888], value=26275
# running time:140.09441256523132
