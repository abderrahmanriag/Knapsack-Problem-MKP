# %%
import operation

def main():
    operation.main()
    
main()
# Out:
# create the init population...
# best solution in init population =16863
# crossover probability pc=0.2, and pc=0.7
# build 500 generations...
# cap=['11927', '13727', '11551', '13056', '13460']
# weights=[11921, 13270, 11356, 12863, 12231], value=26655
# running time:120.52776646614075
