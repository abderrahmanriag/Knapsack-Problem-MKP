# %%
import operation

operation.main()
# Out:
# create the init population...
# best solution in init population =75285
# crossover probability pc=0.2, and pc=0.7
# build 500 generations...
# cap=['61202', '61807', '58959', '62375', '62163']
# weights=[61148, 61450, 58897, 62284, 61669], value=128873
# running time:3246.910310983658
