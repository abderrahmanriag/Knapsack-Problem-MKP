# %% [markdown]
# ## Comparison between GA and GGA

# %%
import GGAvsGA as g    
g.main()
# Out:
# create the init population...
# best solution in init population =75432
# build 500 generations...
# Camparison the GGA with GA, crossover probability=0.2
# cap=['61202', '61807', '58959', '62375', '62163']
# weights=[60848, 61503, 58936, 62287, 62061], value=119835
# running time:1140.6807882785797

# %% [markdown]
# ## Build 500 generations with deffirent crossover probability

# %%
import operation
operation.main()
# Out:
# create the init population...
# best solution in init population =75644
# crossover probability pc=0.2, and pc=0.1
# build 500 generations...
# cap=['61202', '61807', '58959', '62375', '62163']
# weights=[61113, 61715, 58468, 62265, 62093], value=120096
# running time:1761.5841870307922
