# %%
import operation

operation.main()
# Out:
# create the init population...
# best solution in init population =16614
# crossover probability pc=0.2, and pc=0.7
# build 500 generations...
# cap=['13640', '12048', '12574', '13915', '13232', '12190', '12242', '12394', '12258', '10960']
# weights=[13272, 11966, 11636, 13083, 10503, 11729, 12016, 12178, 11923, 7967], value=23402
# running time:310.5890636444092
