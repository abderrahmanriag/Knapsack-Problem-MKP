# %% [markdown]
# ## Comparison between GA and GGA

# %%
import GGAvsGA as g    
g.main()
# Out:
# create the init population...
# best solution in init population =16456
# build 500 generations...
# Camparison the GGA with GA, crossover probability=0.2
# cap=['13640', '12048', '12574', '13915', '13232', '12190', '12242', '12394', '12258', '10960']
# weights=[13549, 11979, 9988, 13424, 11351, 11675, 11570, 12343, 12126, 8763], value=22665
# running time:75.26767182350159

# %% [markdown]
# ## Build 500 generations with deffirent crossover probability

# %%
import operation
operation.main()
# Out:
# create the init population...
# best solution in init population =16089
# crossover probability pc=0.2, and pc=0.1
# build 500 generations...
# cap=['13640', '12048', '12574', '13915', '13232', '12190', '12242', '12394', '12258', '10960']
# weights=[13391, 11964, 11299, 13452, 11475, 12028, 11965, 12186, 11905, 9308], value=22779
# running time:117.48784017562866
