# %%
import operation

operation.main()
# Out:
# create the init population...
# best solution in init population =39541
# crossover probability pc=0.2, and pc=0.7
# build 500 generations...
# cap=['31985', '30902', '31096', '31684', '31802', '31439', '29603', '30621', '32059', '31345']
# weights=[31333, 29995, 30873, 31673, 31572, 31290, 29502, 30503, 31817, 29027], value=63672
# running time:1347.8153610229492
