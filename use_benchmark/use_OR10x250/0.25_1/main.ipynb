# %% [markdown]
# ## Comparison between GA and GGA

# %%
import GGAvsGA as g    
g.main()
# Out:
# create the init population...
# best solution in init population =38298
# build 500 generations...
# Camparison the GGA with GA, crossover probability=0.2
# cap=['31985', '30902', '31096', '31684', '31802', '31439', '29603', '30621', '32059', '31345']
# weights=[28469, 30879, 30677, 31670, 31433, 31287, 28869, 30139, 31843, 30535], value=58614
# running time:396.5650177001953

# %% [markdown]
# ## Build 500 generations with deffirent crossover probability

# %%
import operation
operation.main()
# Out:
# create the init population...
# best solution in init population =38442
# crossover probability pc=0.2, and pc=0.1
# build 500 generations...
# cap=['31985', '30902', '31096', '31684', '31802', '31439', '29603', '30621', '32059', '31345']
# weights=[29069, 30894, 30129, 31125, 31326, 31399, 27278, 30441, 31985, 31240], value=58443
# running time:603.6571664810181
