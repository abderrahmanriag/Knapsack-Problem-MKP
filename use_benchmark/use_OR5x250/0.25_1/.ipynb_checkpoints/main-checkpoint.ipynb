# %%
import operation

operation.main()
# Out:
# create the init population...
# best solution in init population =39020
# crossover probability pc=0.2, and pc=0.7
# build 500 generations...
# cap=['29562', '30027', '32082', '31340', '29959']
# weights=[29553, 29644, 31629, 31294, 27462], value=63664
# running time:1078.8609690666199
