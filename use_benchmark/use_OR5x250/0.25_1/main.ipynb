# %% [markdown]
# ## Comparison between GA and GGA

# %%
import GGAvsGA as g    
g.main()
# Out:
# create the init population...
# best solution in init population =37282
# build 500 generations...
# Camparison the GGA with GA, crossover probability=0.2
# cap=['29562', '30027', '32082', '31340', '29959']
# weights=[29060, 29985, 32080, 31112, 29799], value=59043
# running time:254.97551083564758

# %% [markdown]
# ## Build 500 generations with deffirent crossover probability

# %%
import operation
operation.main()
# Out:
# create the init population...
# best solution in init population =37806
# crossover probability pc=0.2, and pc=0.1
# build 500 generations...
# cap=['29562', '30027', '32082', '31340', '29959']
# weights=[29562, 30007, 31843, 31140, 29777], value=58785
# running time:471.8915388584137
