# %% [markdown]
# ## Comparison between GA and GGA

# %%
import GGAvsGA as g    
g.main()
# Out:
# create the init population...
# best solution in init population =77301
# build 500 generations...
# Camparison the GGA with GA, crossover probability=0.2
# cap=['60589', '62150', '59432', '61740', '62977', '61186', '60721', '60640', '65126', '57802']
# weights=[60325, 61651, 58131, 61285, 61580, 58164, 60711, 60605, 60725, 57768], value=115706
# running time:1409.098764181137

# %% [markdown]
# ## Build 500 generations with deffirent crossover probability

# %%
import operation
operation.main()
# Out:
# create the init population...
# best solution in init population =74661
# crossover probability pc=0.2, and pc=0.1
# build 500 generations...
# cap=['60589', '62150', '59432', '61740', '62977', '61186', '60721', '60640', '65126', '57802']
# weights=[60589, 59610, 59193, 61484, 61637, 58004, 60228, 60579, 63530, 57657], value=116205
# running time:3262.5395567417145
