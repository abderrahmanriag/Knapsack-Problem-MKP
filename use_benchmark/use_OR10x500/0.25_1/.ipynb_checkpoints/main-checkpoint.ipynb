# %%
import operation

operation.main()
# Out:
# create the init population...
# best solution in init population =74622
# crossover probability pc=0.2, and pc=0.7
# build 500 generations...
# cap=['60589', '62150', '59432', '61740', '62977', '61186', '60721', '60640', '65126', '57802']
# weights=[60542, 58685, 59357, 60717, 61926, 58361, 60695, 59861, 62045, 56074], value=118686
# running time:4056.008835554123
